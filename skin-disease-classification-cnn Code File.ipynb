# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Flatten,BatchNormalization
from keras.layers import Conv2D,MaxPooling2D
import os

num_classes = 23
img_rows,img_cols = 48,48
batch_size = 32

# %%
train_data_dir = '../archive/train'
validation_data_dir = '../archive/test'

train_datagen = ImageDataGenerator(
					rescale=1./255,
					rotation_range=30,
					shear_range=0.3,
					zoom_range=0.3,
					width_shift_range=0.4,
					height_shift_range=0.4,
					horizontal_flip=True,
					fill_mode='nearest')

validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
					train_data_dir,
					color_mode='grayscale',
					target_size=(img_rows,img_cols),
					batch_size=batch_size,
					class_mode='categorical',
					shuffle=True)

validation_generator = validation_datagen.flow_from_directory(
							validation_data_dir,
							color_mode='grayscale',
							target_size=(img_rows,img_cols),
							batch_size=batch_size,
							class_mode='categorical',
							shuffle=True)
# Out:
# Found 15557 images belonging to 23 classes.
# Found 4002 images belonging to 23 classes.

# %%
model = Sequential()

# Block-1

model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(img_rows,img_cols,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32,(3,3),padding='same',kernel_initializer='he_normal',input_shape=(img_rows,img_cols,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-2 

model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-3

model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-4 

model.add(Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(256,(3,3),padding='same',kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# Block-5

model.add(Flatten())
model.add(Dense(64,kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-6

model.add(Dense(64,kernel_initializer='he_normal'))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Block-7

model.add(Dense(num_classes,kernel_initializer='he_normal'))
model.add(Activation('softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)        9248
#
#  activation_1 (Activation)   (None, 48, 48, 32)        0
#
#  batch_normalization_1 (Batc  (None, 48, 48, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 32)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)        18496
#
#  activation_2 (Activation)   (None, 24, 24, 64)        0
#
#  batch_normalization_2 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        36928
#
#  activation_3 (Activation)   (None, 24, 24, 64)        0
#
#  batch_normalization_3 (Batc  (None, 24, 24, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       73856
#
#  activation_4 (Activation)   (None, 12, 12, 128)       0
#
#  batch_normalization_4 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       147584
#
#  activation_5 (Activation)   (None, 12, 12, 128)       0
#
#  batch_normalization_5 (Batc  (None, 12, 12, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 256)         295168
#
#  activation_6 (Activation)   (None, 6, 6, 256)         0
#
#  batch_normalization_6 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)         590080
#
#  activation_7 (Activation)   (None, 6, 6, 256)         0
#
#  batch_normalization_7 (Batc  (None, 6, 6, 256)        1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 256)         0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 64)                147520
#
#  activation_8 (Activation)   (None, 64)                0
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  activation_9 (Activation)   (None, 64)                0
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 23)                1495
#
#  activation_10 (Activation)  (None, 23)                0
#
# =================================================================
# Total params: 1,329,207
# Trainable params: 1,327,031
# Non-trainable params: 2,176
# _________________________________________________________________
# None

# %%
from keras.optimizers import RMSprop,SGD,Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint = ModelCheckpoint('skin_disease.h5',
                             monitor='val_loss',
                             mode='min',
                             save_best_only=True,
                             verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=3,
                              verbose=1,
                              min_delta=0.0001)

callbacks = [checkpoint,reduce_lr]

model.compile(loss='categorical_crossentropy',                                                                                                                                                      
              optimizer = Adam(lr=0.001),
              metrics=['accuracy'])

nb_train_samples = 15557
nb_validation_samples = 4002
epochs=25

history=model.fit_generator(
                train_generator,
                steps_per_epoch=nb_train_samples//batch_size,
                epochs=epochs,
                callbacks=callbacks,
                validation_data=validation_generator,
                validation_steps=nb_validation_samples//batch_size)
# Out:
# c:\Users\pushp\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\optimizers\legacy\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# C:\Users\pushp\AppData\Local\Temp\ipykernel_3548\112979621.py:26: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=model.fit_generator(
# Epoch 1/25
# 486/486 [==============================] - ETA: 0s - loss: 3.7030 - accuracy: 0.0730
# Epoch 1: val_loss improved from inf to 2.95851, saving model to skin_disease.h5
# 486/486 [==============================] - 585s 1s/step - loss: 3.7030 - accuracy: 0.0730 - val_loss: 2.9585 - val_accuracy: 0.1020 - lr: 0.0010
# Epoch 2/25
# 486/486 [==============================] - ETA: 0s - loss: 3.1296 - accuracy: 0.0995
# Epoch 2: val_loss improved from 2.95851 to 2.92690, saving model to skin_disease.h5
# 486/486 [==============================] - 518s 1s/step - loss: 3.1296 - accuracy: 0.0995 - val_loss: 2.9269 - val_accuracy: 0.1365 - lr: 0.0010
# Epoch 3/25
# 486/486 [==============================] - ETA: 0s - loss: 2.9793 - accuracy: 0.1185
# Epoch 3: val_loss improved from 2.92690 to 2.92234, saving model to skin_disease.h5
# 486/486 [==============================] - 475s 976ms/step - loss: 2.9793 - accuracy: 0.1185 - val_loss: 2.9223 - val_accuracy: 0.1248 - lr: 0.0010
# Epoch 4/25
# 486/486 [==============================] - ETA: 0s - loss: 2.9170 - accuracy: 0.1300
# Epoch 4: val_loss did not improve from 2.92234
# 486/486 [==============================] - 564s 1s/step - loss: 2.9170 - accuracy: 0.1300 - val_loss: 2.9479 - val_accuracy: 0.1283 - lr: 0.0010
# Epoch 5/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8856 - accuracy: 0.1380
# Epoch 5: val_loss did not improve from 2.92234
# 486/486 [==============================] - 520s 1s/step - loss: 2.8856 - accuracy: 0.1380 - val_loss: 2.9993 - val_accuracy: 0.1105 - lr: 0.0010
# Epoch 6/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8743 - accuracy: 0.1435
# Epoch 6: val_loss did not improve from 2.92234
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 486/486 [==============================] - 468s 962ms/step - loss: 2.8743 - accuracy: 0.1435 - val_loss: 2.9649 - val_accuracy: 0.1238 - lr: 0.0010
# Epoch 7/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8438 - accuracy: 0.1489
# Epoch 7: val_loss improved from 2.92234 to 2.85483, saving model to skin_disease.h5
# 486/486 [==============================] - 604s 1s/step - loss: 2.8438 - accuracy: 0.1489 - val_loss: 2.8548 - val_accuracy: 0.1398 - lr: 2.0000e-04
# Epoch 8/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8309 - accuracy: 0.1542
# Epoch 8: val_loss did not improve from 2.85483
# 486/486 [==============================] - 768s 2s/step - loss: 2.8309 - accuracy: 0.1542 - val_loss: 2.8696 - val_accuracy: 0.1385 - lr: 2.0000e-04
# Epoch 9/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8282 - accuracy: 0.1532
# Epoch 9: val_loss did not improve from 2.85483
# 486/486 [==============================] - 585s 1s/step - loss: 2.8282 - accuracy: 0.1532 - val_loss: 2.8690 - val_accuracy: 0.1455 - lr: 2.0000e-04
# Epoch 10/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8232 - accuracy: 0.1574
# Epoch 10: val_loss did not improve from 2.85483
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 486/486 [==============================] - 527s 1s/step - loss: 2.8232 - accuracy: 0.1574 - val_loss: 2.8580 - val_accuracy: 0.1460 - lr: 2.0000e-04
# Epoch 11/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8117 - accuracy: 0.1591
# Epoch 11: val_loss improved from 2.85483 to 2.83089, saving model to skin_disease.h5
# 486/486 [==============================] - 526s 1s/step - loss: 2.8117 - accuracy: 0.1591 - val_loss: 2.8309 - val_accuracy: 0.1530 - lr: 4.0000e-05
# Epoch 12/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8029 - accuracy: 0.1596
# Epoch 12: val_loss improved from 2.83089 to 2.81444, saving model to skin_disease.h5
# 486/486 [==============================] - 489s 1s/step - loss: 2.8029 - accuracy: 0.1596 - val_loss: 2.8144 - val_accuracy: 0.1542 - lr: 4.0000e-05
# Epoch 13/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8013 - accuracy: 0.1626
# Epoch 13: val_loss did not improve from 2.81444
# 486/486 [==============================] - 488s 1s/step - loss: 2.8013 - accuracy: 0.1626 - val_loss: 2.8259 - val_accuracy: 0.1555 - lr: 4.0000e-05
# Epoch 14/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7951 - accuracy: 0.1648
# Epoch 14: val_loss improved from 2.81444 to 2.80782, saving model to skin_disease.h5
# 486/486 [==============================] - 3237s 7s/step - loss: 2.7951 - accuracy: 0.1648 - val_loss: 2.8078 - val_accuracy: 0.1577 - lr: 4.0000e-05
# Epoch 15/25
# 486/486 [==============================] - ETA: 0s - loss: 2.8076 - accuracy: 0.1599
# Epoch 15: val_loss improved from 2.80782 to 2.79533, saving model to skin_disease.h5
# 486/486 [==============================] - 465s 957ms/step - loss: 2.8076 - accuracy: 0.1599 - val_loss: 2.7953 - val_accuracy: 0.1618 - lr: 4.0000e-05
# Epoch 16/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7897 - accuracy: 0.1633
# Epoch 16: val_loss improved from 2.79533 to 2.78756, saving model to skin_disease.h5
# 486/486 [==============================] - 444s 914ms/step - loss: 2.7897 - accuracy: 0.1633 - val_loss: 2.7876 - val_accuracy: 0.1667 - lr: 4.0000e-05
# Epoch 17/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7874 - accuracy: 0.1648
# Epoch 17: val_loss did not improve from 2.78756
# 486/486 [==============================] - 552s 1s/step - loss: 2.7874 - accuracy: 0.1648 - val_loss: 2.8160 - val_accuracy: 0.1565 - lr: 4.0000e-05
# Epoch 18/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7899 - accuracy: 0.1650
# Epoch 18: val_loss did not improve from 2.78756
# 486/486 [==============================] - 614s 1s/step - loss: 2.7899 - accuracy: 0.1650 - val_loss: 2.8243 - val_accuracy: 0.1645 - lr: 4.0000e-05
# Epoch 19/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7816 - accuracy: 0.1652
# Epoch 19: val_loss did not improve from 2.78756
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 486/486 [==============================] - 564s 1s/step - loss: 2.7816 - accuracy: 0.1652 - val_loss: 2.7892 - val_accuracy: 0.1655 - lr: 4.0000e-05
# Epoch 20/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7842 - accuracy: 0.1651
# Epoch 20: val_loss did not improve from 2.78756
# 486/486 [==============================] - 569s 1s/step - loss: 2.7842 - accuracy: 0.1651 - val_loss: 2.7891 - val_accuracy: 0.1682 - lr: 8.0000e-06
# Epoch 21/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7821 - accuracy: 0.1704
# Epoch 21: val_loss improved from 2.78756 to 2.78198, saving model to skin_disease.h5
# 486/486 [==============================] - 631s 1s/step - loss: 2.7821 - accuracy: 0.1704 - val_loss: 2.7820 - val_accuracy: 0.1678 - lr: 8.0000e-06
# Epoch 22/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7754 - accuracy: 0.1673
# Epoch 22: val_loss did not improve from 2.78198
# 486/486 [==============================] - 644s 1s/step - loss: 2.7754 - accuracy: 0.1673 - val_loss: 2.7934 - val_accuracy: 0.1665 - lr: 8.0000e-06
# Epoch 23/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7764 - accuracy: 0.1684
# Epoch 23: val_loss improved from 2.78198 to 2.77956, saving model to skin_disease.h5
# 486/486 [==============================] - 890s 2s/step - loss: 2.7764 - accuracy: 0.1684 - val_loss: 2.7796 - val_accuracy: 0.1647 - lr: 8.0000e-06
# Epoch 24/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7803 - accuracy: 0.1695
# Epoch 24: val_loss did not improve from 2.77956
# 486/486 [==============================] - 634s 1s/step - loss: 2.7803 - accuracy: 0.1695 - val_loss: 2.7865 - val_accuracy: 0.1645 - lr: 8.0000e-06
# Epoch 25/25
# 486/486 [==============================] - ETA: 0s - loss: 2.7778 - accuracy: 0.1687
# Epoch 25: val_loss did not improve from 2.77956
# 486/486 [==============================] - 647s 1s/step - loss: 2.7778 - accuracy: 0.1687 - val_loss: 2.7844 - val_accuracy: 0.1663 - lr: 8.0000e-06
